# %% [markdown]
# # Solving Diffution Equation with SA-PINN

# %% [markdown]
# ## Problem Setup
# Diffusion Equation:
#
# $$u_t = u_xx - e^{-t}(\sin(\pi x) - \pi^2\sin(\pi x)) \quad x \in [-1, 1], t\in [0, 1]$$
#
# Initial Condition: $$u(x, 0) = \sin(\pi x)$$
# Boudary Conditions: $$u(-1, t) = u(1, t) = 0$$
# Exact solution: $$u(x, t) = e^{-t}\sin(\pi x)$$

# %% [markdown]
# ## Install and Import Libraries

# %%
# !pip install pyDOE
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pyDOE) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pyDOE) (1.10.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18184 sha256=51a195fe5b6dc6fb7e2060840460d6f6205a9b730713fe7a7c1b71ad25f4c3d9
#   Stored in directory: /root/.cache/pip/wheels/00/3e/fa/5705bf59c2053c17c4799c3ab66a2e356c32f40a3044fe2134
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
from pyDOE import lhs
import tensorflow as tf
import numpy as np
import scipy.optimize
import scipy.io

np.random.seed(1234)
tf.random.set_seed(1234)

# %% [markdown]
# ### Check GPU Status

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Mar  4 07:50:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11802280120051195330
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14385217536
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6455140676743085347
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %% [markdown]
# ## Generate Dataset

# %%
def exact_solution(dataset):
    x = dataset[:, 0]
    t = dataset[:, 1]
    return np.exp(-t) * np.sin(np.pi * x)

# %%
xmin = -1.0
xmax = 1.0
tmin = 0
tmax = 1.0

## test set: 101 x 101 uniform grid
x_test = np.linspace(xmin, xmax, 101)
t_test = np.linspace(tmin, tmax, 101)
X, T = np.meshgrid(x_test, t_test)
X_u_test = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))
# exact solution
u_e = exact_solution(X_u_test)[:, None] # shape: 10201 x 1

lb = X_u_test[0]
ub = X_u_test[-1]

## training set

# training data for initial condition
ic_point_count = 100

b_x = xmin + (xmax - xmin) * np.random.rand(ic_point_count, 1)
X_train_IC = np.hstack((b_x, np.zeros_like(b_x)))
u_train_IC = np.sin(np.pi * X_train_IC[:, 0])[:, None]

# training data for boundary conditions
bc_point_count_each = 100

b_t = tmin + (tmax - tmin) * np.random.rand(bc_point_count_each, 1)
X_train_BC_bottom = np.hstack((np.ones_like(b_t) * xmin, b_t))
u_train_BC_bottom = np.zeros_like(b_t)

X_train_BC_top = np.hstack((np.ones_like(b_t) * xmax, b_t))
u_train_BC_top = np.zeros_like(b_t)

N_u = 100 + 2 * 100
X_u_train = np.vstack([X_train_IC, X_train_BC_bottom, X_train_BC_top])
u_train = np.vstack([u_train_IC, u_train_BC_bottom, u_train_BC_top])

# training set for the PDE
N_f = 8000

# Latin Hypercube sampling for the collocation points
X_f_train = lb + (ub - lb) * lhs(2, N_f)
X_f_train = np.vstack((X_f_train, X_u_train)) # 把边界点也加进pde的训练集中

# %% [markdown]
# ## Define SA-PINN Model

# %%
class SAPINN(tf.Module):
    """
    Define a SA-PINN for approximation the solution of burgers equation.

    Params:
      layers: an array of each layer's width(num of neurons)
      lb: [xmin, tmin],
      ub: [xmax, tmax]
    """
    def __init__(self, layers, lb, ub):
        self.weights = [] # list of model's parameters(weights and bias)
        self.parameters_num = 0 # numbers of model's parameters
        self.layers = layers
        self.lb = lb
        self.ub = ub
        self.epoch = 0 

        # setup model weights
        for i in range(len(layers)-1):
            input_dim = layers[i]
            output_dim = layers[i+1]

            std = np.sqrt(2 / (input_dim + output_dim))

            w_value = tf.random.normal([input_dim, output_dim], stddev=std, dtype='float64')
            w = tf.Variable(w_value, trainable=True, name=f'w{i+1}')
            self.weights.append(w)

            b_value = tf.zeros([output_dim, ], dtype='float64')
            b = tf.Variable(b_value, trainable=True, name=f'b{i+1}')
            self.weights.append(b)

            # num += num_of_weight + num_of_bias
            self.parameters_num += input_dim * output_dim + output_dim
    
        # self-adaptive weights

        ## boundary weights
        self.u_weights = tf.Variable(tf.ones([N_u, 1], dtype="float64"), trainable=True, name='boundary_weight')

        ## residual weights
        self.f_weights = tf.Variable(tf.ones([N_f+N_u, 1], dtype='float64'), trainable=True, name='pde_weight')

    def __call__(self, X):
        """
        Define forward pass, i.e. use model to predict the result

        Params:
          X: the dataset, that will be used to predict
        """
        x = X
        x = (x - self.lb) / (self.ub - self.lb)

        # applying activation function
        for i in range(len(self.layers)-2):
            # x = activation_function(wx + b)
            x = tf.nn.tanh(tf.add(tf.matmul(x, self.weights[2*i]), self.weights[2*i+1]))

        # output layer(without activation function)
        x = tf.add(tf.matmul(x, self.weights[-2]), self.weights[-1])
        return x

    def loss_BC_IC(self, X_u_train, u_train):
        """
        Calculate the loss score of boundary condition and initial condition

        Params:
          X_u_train: training set of boundary condition and initial condition
          u_train: exact `u` value at the BC/IC training set (since we have the data of `u`, we can use part of it to train model)
        """

        # element-wise multiply by adaptive weights of boundary
        loss_u = self.u_weights * (u_train - self(X_u_train))
        loss_u = tf.reduce_mean(tf.square(loss_u))
        return loss_u

    def loss_PDE(self, X_f_train):
        """
        Calculate the loss score of PDE

        Params: 
          X_f_train: trainning set of PDE as well as BC/IC (I've concatenated them above)
        """
    
        X = tf.Variable(X_f_train, dtype = 'float64', trainable=False)

        x_f = X[:, 0:1]
        t_f = X[:, 1:2]

        with tf.GradientTape(persistent=True) as tape:

            tape.watch(x_f)
            tape.watch(t_f)

            # tf.stack([x_f[:, 0], t_f[:, 0]], axis=1) <=> X
            # It's been destructured then stacked because we need the gradients of x and t
            X = tf.stack([x_f[:, 0], t_f[:, 0]], axis=1)   

            u = self(X)
            u_x = tape.gradient(u, x_f)

        u_t = tape.gradient(u, t_f)    
        u_xx = tape.gradient(u_x, x_f)

        del tape

        # f: residual of pde
        f = u_t - u_xx + tf.exp(-t_f) * (tf.sin(np.pi * x_f) - np.pi**2 * tf.sin(np.pi * x_f))

        # element-wise multiply by adaptive weights of residual
        loss_f = tf.reduce_mean(tf.square(self.f_weights * f))

        return loss_f

    def loss(self, X_u_train, u_train, X_f_train):

        """
        Calculate total loss of the model

        Params:
          X_u_train: training set of boundary condition and initial condition
          u_train: exact `u` value at the BC/IC training set
          X_f_train: trainning set of PDE as well as BC/IC
        """

        loss_u = self.loss_BC_IC(self.X_u_train, self.u_train)
        loss_f = self.loss_PDE(self.X_f_train)

        loss = loss_u + loss_f

        return loss, loss_u, loss_f

    def set_training_set(self, X_u_train, u_train, X_f_train):
        """
        set training set for the model.

        X_u_train: training set of boundary condition and initial condition
        u_train: exact `u` value at the BC/IC training set
        X_f_train: trainning set of PDE as well as BC/IC
        """
        
        self.X_u_train = X_u_train
        self.u_train = u_train
        self.X_f_train = X_f_train

    def get_weights(self):
        """
        Return a 'long' tensor of model weights' current value
        """

        long_weights_tensor = []

        for i in range(len(self.layers)-1):
            # flatten weights and biases
            w_1d = tf.reshape(self.weights[2*i], [-1]) 
            b_1d = tf.reshape(self.weights[2*i+1], [-1])

            # then concatenate them into a single tensor
            long_weights_tensor = tf.concat([long_weights_tensor, w_1d], axis=0)
            long_weights_tensor = tf.concat([long_weights_tensor, b_1d], axis=0)

        return long_weights_tensor

    def set_weights(self, parameters):
        """
        Set model weights, given new weights values(stored in parameters)

        Params:
          parameters: a "long" tensor of new model weights, whose size and shape fit `long_weights_tensor` defined in self.get_weights()
        """

        # Since `parameters` is a long tensor, we have to destructure it to update model weights.
        # To do that, we need shape and size of each weight and bias

        for i in range(len(self.layers)-1):
            w_shape = tf.shape(self.weights[2*i]).numpy()
            w_size = tf.size(self.weights[2*i]).numpy()

            # pick new weight in `parameters`
            new_w = parameters[0:w_size]
            self.weights[2*i].assign(tf.reshape(new_w, w_shape))
            parameters = np.delete(parameters, np.arange(w_size), axis=0) # delete this part from `parameters`, so we can get next bias from index 0

            b_shape = tf.shape(self.weights[2*i+1]).numpy()
            b_size = tf.size(self.weights[2*i+1]).numpy()

             # pick new bias in `parameters`
            new_b = parameters[0:b_size]
            self.weights[2*i+1].assign(tf.reshape(new_b, b_shape))
            parameters = np.delete(parameters, np.arange(b_size), axis=0) # delete this part from `parameters`, so we can get next weight from index 0

    def optimizer_func(self, parameters):
        """
        Define an optimizer function for scipy's l-bfgs optimizer

        Params:
          parameters: a "long" tensor of new model weights, whose size and shape fit `long_weights_tensor` defined in self.get_weights()

        Returns:
          loss.numpy(): loss score of the model
          gradients_1d.numpy(): a numpy array of gradients
        """

        self.set_weights(parameters) # set new weights

        with tf.GradientTape() as tape:
            tape.watch(self.weights)
            
            # loss after update
            loss, loss_u, loss_f = self.loss(self.X_u_train, self.u_train, self.X_f_train)

        gradients = tape.gradient(loss, self.weights)

        del tape

        gradients_1d = [] # flatten gradients, like `long_weights_tensor` defined in self.get_weights()

        for i in range(len(self.layers)-1):
            # flatten gradients of weights and biases
            gradients_w_1d = tf.reshape(gradients[2*i], [-1]) 
            gradients_b_1d = tf.reshape(gradients[2*i+1], [-1])

            # then concatenate them into a single tensor
            gradients_1d = tf.concat([gradients_1d, gradients_w_1d], 0) 
            gradients_1d = tf.concat([gradients_1d, gradients_b_1d], 0)

        return loss.numpy(), gradients_1d.numpy()

    def optimizer_callback(self, parameters):
        """
        Define an optimizer callback function
        """

        loss, loss_u, loss_f = self.loss(self.X_u_train, self.u_train, self.X_f_train)

        # calculate L2 error at this epoch
        u_pred = self(X_u_test).numpy()
        L2_error = np.linalg.norm((u_e - u_pred), 2) / np.linalg.norm(u_e, 2)

        # print loss, loss_u, loss_f, L2_error at this epoch
        self.epoch += 1
        tf.print(f"epoch: {self.epoch} loss:{loss:.5f} loss_u: {loss_u:.5f} loss_f: {loss_f:.5f} L2_error: {L2_error:.5f}")

    def adaptive_gradients(self):
        """
        Calculate model weights' gradients, as well as adaptive weights' gradients
        """

        with tf.GradientTape() as tape:
            tape.watch(self.weights)

            loss, loss_u, loss_f = self.loss(self.X_u_train, self.u_train, self.X_f_train)

        # gradients of model' weights
        gradients = tape.gradient(loss, self.weights)

        del tape

        with tf.GradientTape(persistent=True) as tape:
            tape.watch(self.u_weights)
            tape.watch(self.f_weights)

            loss, loss_u, loss_f = self.loss(self.X_u_train, self.u_train, self.X_f_train)

        # gradients of adaptive weiths
        gradient_u_weights = tape.gradient(loss, self.u_weights)
        gradient_f_weights = tape.gradient(loss, self.f_weights)

        del tape

        return loss, gradients, gradient_u_weights, gradient_f_weights

# %% [markdown]
# ## Load Model
#
# Load model from previously saved model. (See **Save Model below**)

# %%
import json

def load_model(model_path):
    """
    return an trained SA-PINN model for burgers equation
    
    params:
      model_path: path of json file that contains model's data
    """
    
    with open(model_path, 'r') as f:
        model_data = json.load(f)
        f.close()
    
    # data
    layers = np.array(model_data['layers'])
    model_weights = np.array(model_data['model_weights'])
    model_adaptive_weights = model_data['model_adaptive_weights']

    model =  SAPINN(layers, lb, ub) # SAPINN, lb, ub must be defined before you load the model
    model.set_training_set(X_u_train, X_f_train) # X_u_train, X_f_train must be defined before you load the model
    model.set_weights(model_weights)
    model.u_weights.assign(np.array(model_adaptive_weights[0]))
    model.f_weights.assign(np.array(model_adaptive_weights[1]))
    
    return model

# %%
model_path = 'models/SAPINNmodel.json' # your model path

sa_pinn = load_model(model_path)

# %% [markdown]
# ## Train the Model

# %%
layers = np.array([2, 32, 64, 32, 1])
sa_pinn = SAPINN(layers, lb, ub)
sa_pinn.set_training_set(X_u_train, u_train, X_f_train)

# firstly, use Tensorflow Adam optimizer to apply gradient descent/ascent
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
optimizer_u_weight = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
optimizer_f_weight = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7)

adam_epochs = 5000
print("Starting Adam training")
for epoch in range(adam_epochs):

    loss, gradients, gradient_u_weights, gradient_f_weights = sa_pinn.adaptive_gradients()


    print(f"epoch: {epoch+1} loss: {loss.numpy():.5f}")

    # apply gradient descent on model weights
    optimizer.apply_gradients(zip(gradients, sa_pinn.weights))
    # apply gradient ascent on adaptive weights
    optimizer_u_weight.apply_gradients(zip([-gradient_u_weights], [sa_pinn.u_weights]))
    optimizer_f_weight.apply_gradients(zip([-gradient_f_weights], [sa_pinn.f_weights]))

# then, use scipy l-bfgs optimizer to train model
lbfgs_epochs = 5000
print("Starting L-BFGS training")
options = {
    'disp': None,
    'maxcor': 200, 
    'ftol': 1 * np.finfo(float).eps,  #The iteration stops when (f^k - f^{k+1})/max{|f^k|,|f^{k+1}|,1} <= ftol
    'gtol': 5e-8, 
    'maxfun':  50000, 
    'maxiter': lbfgs_epochs,
    'iprint': -1,   #print update every 50 iterations
    'maxls': 50}

results = scipy.optimize.minimize(
    fun=sa_pinn.optimizer_func,
    x0=sa_pinn.get_weights().numpy(),
    args=(),
    method='L-BFGS-B',
    jac=True,
    callback=sa_pinn.optimizer_callback,
    options=options
)
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: 1 loss:0.00017 loss_u: 0.00003 loss_f: 0.00014 L2_error: 0.00392
# epoch: 2 loss:0.00016 loss_u: 0.00003 loss_f: 0.00014 L2_error: 0.00387
# epoch: 3 loss:0.00015 loss_u: 0.00003 loss_f: 0.00013 L2_error: 0.00362
# epoch: 4 loss:0.00015 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00359
# epoch: 5 loss:0.00015 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00351
# epoch: 6 loss:0.00015 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00349
# epoch: 7 loss:0.00015 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00351
# epoch: 8 loss:0.00015 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00357
# epoch: 9 loss:0.00015 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00359
# epoch: 10 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00359
# epoch: 11 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00355
# epoch: 12 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00355
# epoch: 13 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00354
# epoch: 14 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00353
# epoch: 15 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00352
# epoch: 16 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00351
# epoch: 17 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00351
# epoch: 18 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00350
# epoch: 19 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00351
# epoch: 20 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00353
# epoch: 21 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00353
# epoch: 22 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00351
# epoch: 23 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00349
# epoch: 24 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00346
# epoch: 25 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00344
# epoch: 26 loss:0.00014 loss_u: 0.00003 loss_f: 0.00012 L2_error: 0.00341
# epoch: 27 loss:0.00014 loss_u: 0.00002 loss_f: 0.00012 L2_error: 0.00337
# epoch: 28 loss:0.00014 loss_u: 0.00002 loss_f: 0.00012 L2_error: 0.00331
# epoch: 29 loss:0.00014 loss_u: 0.00002 loss_f: 0.00012 L2_error: 0.00323
# epoch: 30 loss:0.00014 loss_u: 0.00002 loss_f: 0.00012 L2_error: 0.00319
# epoch: 31 loss:0.00014 loss_u: 0.00002 loss_f: 0.00012 L2_error: 0.00317
# epoch: 32 loss:0.00014 loss_u: 0.00002 loss_f: 0.00012 L2_error: 0.00315
# epoch: 33 loss:0.00013 loss_u: 0.00002 loss_f: 0.00011 L2_error: 0.00312
# epoch: 34 loss:0.00013 loss_u: 0.00002 loss_f: 0.00011 L2_error: 0.00307
# epoch: 35 loss:0.00013 loss_u: 0.00002 loss_f: 0.00011 L2_error: 0.00302
# epoch: 36 loss:0.00013 loss_u: 0.00002 loss_f: 0.00011 L2_error: 0.00298
# epoch: 37 loss:0.00012 loss_u: 0.00002 loss_f: 0.00011 L2_error: 0.00291
# epoch: 38 loss:0.00012 loss_u: 0.00002 loss_f: 0.00011 L2_error: 0.00292
# epoch: 39 loss:0.00012 loss_u: 0.00002 loss_f: 0.00011 L2_error: 0.00291
# epoch: 40 loss:0.00012 loss_u: 0.00001 loss_f: 0.00011 L2_error: 0.00292
# epoch: 41 loss:0.00012 loss_u: 0.00001 loss_f: 0.00011 L2_error: 0.00289
# epoch: 42 loss:0.00012 loss_u: 0.00001 loss_f: 0.00011 L2_error: 0.00290
# epoch: 43 loss:0.00012 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00286
# epoch: 44 loss:0.00012 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00284
# epoch: 45 loss:0.00012 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00281
# epoch: 46 loss:0.00012 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00279
# epoch: 47 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00278
# epoch: 48 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00275
# epoch: 49 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00270
# epoch: 50 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00266
# epoch: 51 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00265
# epoch: 52 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00267
# epoch: 53 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00268
# epoch: 54 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00269
# epoch: 55 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00271
# epoch: 56 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00279
# epoch: 57 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00286
# epoch: 58 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00291
# epoch: 59 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00291
# epoch: 60 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00290
# epoch: 61 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00288
# epoch: 62 loss:0.00011 loss_u: 0.00001 loss_f: 0.00010 L2_error: 0.00286
# epoch: 63 loss:0.00011 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00284
# epoch: 64 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00286
# epoch: 65 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00284
# epoch: 66 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00277
# epoch: 67 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00266
# epoch: 68 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00265
# epoch: 69 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00267
# epoch: 70 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00271
# epoch: 71 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00272
# epoch: 72 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00269
# epoch: 73 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00266
# epoch: 74 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00263
# epoch: 75 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00261
# epoch: 76 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00262
# epoch: 77 loss:0.00010 loss_u: 0.00001 loss_f: 0.00009 L2_error: 0.00267
# epoch: 78 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00274
# epoch: 79 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00278
# epoch: 80 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00280
# epoch: 81 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00281
# epoch: 82 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00283
# epoch: 83 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00285
# epoch: 84 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00283
# epoch: 85 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00284
# epoch: 86 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00284
# epoch: 87 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00284
# epoch: 88 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00278
# epoch: 89 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00270
# epoch: 90 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00265
# epoch: 91 loss:0.00009 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00261
# epoch: 92 loss:0.00008 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00258
# epoch: 93 loss:0.00008 loss_u: 0.00001 loss_f: 0.00008 L2_error: 0.00252
# epoch: 94 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00247
# epoch: 95 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00244
# epoch: 96 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00247
# epoch: 97 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00250
# epoch: 98 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00250
# epoch: 99 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00250
# epoch: 100 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00250
# epoch: 101 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00249
# epoch: 102 loss:0.00008 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00249
# epoch: 103 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00249
# epoch: 104 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00248
# epoch: 105 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00248
# epoch: 106 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00248
# epoch: 107 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00249
# epoch: 108 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00249
# epoch: 109 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00250
# epoch: 110 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00251
# epoch: 111 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00252
# epoch: 112 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00255
# epoch: 113 loss:0.00007 loss_u: 0.00001 loss_f: 0.00007 L2_error: 0.00259
# epoch: 114 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00264
# epoch: 115 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00266
# epoch: 116 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00265
# epoch: 117 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00263
# epoch: 118 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00259
# epoch: 119 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00253
# epoch: 120 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00247
# epoch: 121 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00245
# epoch: 122 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00246
# epoch: 123 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00249
# epoch: 124 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00249
# epoch: 125 loss:0.00007 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00254
# epoch: 126 loss:0.00006 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00258
# epoch: 127 loss:0.00006 loss_u: 0.00001 loss_f: 0.00006 L2_error: 0.00269
# epoch: 128 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00269
# epoch: 129 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00271
# epoch: 130 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00271
# epoch: 131 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00273
# epoch: 132 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00274
# epoch: 133 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00274
# epoch: 134 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00271
# epoch: 135 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00262
# epoch: 136 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00251
# epoch: 137 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00246
# epoch: 138 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00245
# epoch: 139 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00245
# epoch: 140 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00245
# epoch: 141 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00247
# epoch: 142 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00250
# epoch: 143 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00254
# epoch: 144 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00260
# epoch: 145 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00259
# epoch: 146 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00262
# epoch: 147 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00259
# epoch: 148 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00258
# epoch: 149 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00257
# epoch: 150 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00256
# epoch: 151 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00256
# epoch: 152 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00255
# epoch: 153 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00254
# epoch: 154 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00253
# epoch: 155 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00251
# epoch: 156 loss:0.00006 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00248
# epoch: 157 loss:0.00005 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00244
# epoch: 158 loss:0.00005 loss_u: 0.00001 loss_f: 0.00005 L2_error: 0.00240
# epoch: 159 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00240
# epoch: 160 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00238
# epoch: 161 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00246
# epoch: 162 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00242
# epoch: 163 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00245
# epoch: 164 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00245
# epoch: 165 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00245
# epoch: 166 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00244
# epoch: 167 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00244
# epoch: 168 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00244
# epoch: 169 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00244
# epoch: 170 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00244
# epoch: 171 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00244
# epoch: 172 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00243
# epoch: 173 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00246
# epoch: 174 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00242
# epoch: 175 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00244
# epoch: 176 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00241
# epoch: 177 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00239
# epoch: 178 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00238
# epoch: 179 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00237
# epoch: 180 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00237
# epoch: 181 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00236
# epoch: 182 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00236
# epoch: 183 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00235
# epoch: 184 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00235
# epoch: 185 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00237
# epoch: 186 loss:0.00005 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00241
# epoch: 187 loss:0.00004 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00245
# epoch: 188 loss:0.00004 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00246
# epoch: 189 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00245
# epoch: 190 loss:0.00004 loss_u: 0.00001 loss_f: 0.00004 L2_error: 0.00242
# epoch: 191 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00243
# epoch: 192 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00243
# epoch: 193 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00243
# epoch: 194 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00242
# epoch: 195 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00242
# epoch: 196 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00242
# epoch: 197 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00239
# epoch: 198 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00236
# epoch: 199 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00234
# epoch: 200 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 201 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00226
# epoch: 202 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00227
# epoch: 203 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00229
# epoch: 204 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00232
# epoch: 205 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00233
# epoch: 206 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00233
# epoch: 207 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00233
# epoch: 208 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00232
# epoch: 209 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 210 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00229
# epoch: 211 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 212 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 213 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 214 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 215 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 216 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 217 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00230
# epoch: 218 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00231
# epoch: 219 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00232
# epoch: 220 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00233
# epoch: 221 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00234
# epoch: 222 loss:0.00004 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00235
# epoch: 223 loss:0.00003 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00239
# epoch: 224 loss:0.00003 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00244
# epoch: 225 loss:0.00003 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00235
# epoch: 226 loss:0.00003 loss_u: 0.00001 loss_f: 0.00003 L2_error: 0.00234
# epoch: 227 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00229
# epoch: 228 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00229
# epoch: 229 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00232
# epoch: 230 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00233
# epoch: 231 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00232
# epoch: 232 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00234
# epoch: 233 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00232
# epoch: 234 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00233
# epoch: 235 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00235
# epoch: 236 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00235
# epoch: 237 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00235
# epoch: 238 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00236
# epoch: 239 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00237
# epoch: 240 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00236
# epoch: 241 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00236
# epoch: 242 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00237
# epoch: 243 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00238
# epoch: 244 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00238
# epoch: 245 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00239
# epoch: 246 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00240
# epoch: 247 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00240
# epoch: 248 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00240
# epoch: 249 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00241
# epoch: 250 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00241
# epoch: 251 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00242
# epoch: 252 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00241
# epoch: 253 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 254 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 255 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 256 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00246
# epoch: 257 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 258 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00247
# epoch: 259 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 260 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 261 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 262 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 263 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 264 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00248
# epoch: 265 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 266 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00252
# epoch: 267 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00252
# epoch: 268 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 269 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 270 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 271 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00252
# epoch: 272 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00252
# epoch: 273 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 274 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00248
# epoch: 275 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00247
# epoch: 276 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00247
# epoch: 277 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00246
# epoch: 278 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00246
# epoch: 279 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 280 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 281 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 282 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 283 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 284 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 285 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 286 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 287 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 288 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 289 loss:0.00003 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 290 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00247
# epoch: 291 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00246
# epoch: 292 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 293 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 294 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00243
# epoch: 295 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 296 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00244
# epoch: 297 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00245
# epoch: 298 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00247
# epoch: 299 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00248
# epoch: 300 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00250
# epoch: 301 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 302 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 303 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00250
# epoch: 304 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00250
# epoch: 305 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00250
# epoch: 306 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00250
# epoch: 307 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00250
# epoch: 308 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00251
# epoch: 309 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00253
# epoch: 310 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00258
# epoch: 311 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00260
# epoch: 312 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00264
# epoch: 313 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00264
# epoch: 314 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00267
# epoch: 315 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00268
# epoch: 316 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00266
# epoch: 317 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00266
# epoch: 318 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00267
# epoch: 319 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00268
# epoch: 320 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00267
# epoch: 321 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00269
# epoch: 322 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00267
# epoch: 323 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00267
# epoch: 324 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00266
# epoch: 325 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00264
# epoch: 326 loss:0.00002 loss_u: 0.00001 loss_f: 0.00002 L2_error: 0.00263
# epoch: 327 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00261
# epoch: 328 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00261
# epoch: 329 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00262
# epoch: 330 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00262
# epoch: 331 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00262
# epoch: 332 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00259
# epoch: 333 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00258
# epoch: 334 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00259
# epoch: 335 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00258
# epoch: 336 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00258
# epoch: 337 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00258
# epoch: 338 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00258
# epoch: 339 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00258
# epoch: 340 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00257
# epoch: 341 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00257
# epoch: 342 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00256
# epoch: 343 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00255
# epoch: 344 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00254
# epoch: 345 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00253
# epoch: 346 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00253
# epoch: 347 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00252
# epoch: 348 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00252
# epoch: 349 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00251
# epoch: 350 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00250
# epoch: 351 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00249
# epoch: 352 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00245
# epoch: 353 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00243
# epoch: 354 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00237
# epoch: 355 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00234
# epoch: 356 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00233
# epoch: 357 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00234
# epoch: 358 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00233
# epoch: 359 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00234
# epoch: 360 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00236
# epoch: 361 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00237
# epoch: 362 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00239
# epoch: 363 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00239
# epoch: 364 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00239
# epoch: 365 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 366 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 367 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 368 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 369 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 370 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 371 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 372 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 373 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00240
# epoch: 374 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00239
# epoch: 375 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00239
# epoch: 376 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00238
# epoch: 377 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00238
# epoch: 378 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00239
# epoch: 379 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00238
# epoch: 380 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00239
# epoch: 381 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00238
# epoch: 382 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00235
# epoch: 383 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00235
# epoch: 384 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00233
# epoch: 385 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00231
# epoch: 386 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00232
# epoch: 387 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00231
# epoch: 388 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00230
# epoch: 389 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00229
# epoch: 390 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00228
# epoch: 391 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00227
# epoch: 392 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00226
# epoch: 393 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00225
# epoch: 394 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00225
# epoch: 395 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00224
# epoch: 396 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00223
# epoch: 397 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00223
# epoch: 398 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00223
# epoch: 399 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00224
# epoch: 400 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00226
# epoch: 401 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00226
# epoch: 402 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00225
# epoch: 403 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00226
# epoch: 404 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00225
# epoch: 405 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00224
# epoch: 406 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00225
# epoch: 407 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00225
# epoch: 408 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00226
# epoch: 409 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00227
# epoch: 410 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00227
# epoch: 411 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00227
# epoch: 412 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00224
# epoch: 413 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00222
# epoch: 414 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00222
# epoch: 415 loss:0.00002 loss_u: 0.00001 loss_f: 0.00001 L2_error: 0.00221
# epoch: 416 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00220
# epoch: 417 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00220
# epoch: 418 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00219
# epoch: 419 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00221
# epoch: 420 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00215
# epoch: 421 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00211
# epoch: 422 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00210
# epoch: 423 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00209
# epoch: 424 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00208
# epoch: 425 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00205
# epoch: 426 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00203
# epoch: 427 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00201
# epoch: 428 loss:0.00002 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00200
# epoch: 429 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00198
# epoch: 430 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00196
# epoch: 431 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00194
# epoch: 432 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00195
# epoch: 433 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00197
# epoch: 434 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00199
# epoch: 435 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00200
# epoch: 436 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00200
# epoch: 437 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00196
# epoch: 438 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00195
# epoch: 439 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00189
# epoch: 440 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00190
# epoch: 441 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00191
# epoch: 442 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00190
# epoch: 443 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00189
# epoch: 444 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 445 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 446 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 447 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 448 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 449 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 450 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00189
# epoch: 451 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00190
# epoch: 452 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00190
# epoch: 453 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00190
# epoch: 454 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00189
# epoch: 455 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 456 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 457 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 458 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 459 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 460 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 461 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 462 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 463 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 464 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 465 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 466 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00184
# epoch: 467 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00184
# epoch: 468 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 469 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 470 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 471 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 472 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 473 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 474 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 475 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 476 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 477 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 478 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 479 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 480 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 481 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 482 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 483 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 484 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 485 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00186
# epoch: 486 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 487 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 488 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 489 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 490 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 491 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 492 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 493 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00189
# epoch: 494 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00188
# epoch: 495 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00189
# epoch: 496 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00187
# epoch: 497 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00185
# epoch: 498 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00181
# epoch: 499 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00177
# epoch: 500 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00172
# epoch: 501 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00170
# epoch: 502 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00170
# epoch: 503 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00170
# epoch: 504 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 505 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 506 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 507 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00169
# epoch: 508 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 509 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 510 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 511 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 512 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 513 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 514 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 515 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 516 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 517 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 518 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 519 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 520 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 521 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 522 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 523 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 524 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 525 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 526 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 527 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 528 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 529 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 530 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 531 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 532 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 533 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 534 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 535 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 536 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 537 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 538 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 539 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 540 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 541 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 542 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 543 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 544 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 545 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 546 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00170
# epoch: 547 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00169
# epoch: 548 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00169
# epoch: 549 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00174
# epoch: 550 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 551 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00169
# epoch: 552 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00169
# epoch: 553 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00175
# epoch: 554 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00172
# epoch: 555 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00171
# epoch: 556 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00170
# epoch: 557 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 558 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 559 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00169
# epoch: 560 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00168
# epoch: 561 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 562 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 563 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00167
# epoch: 564 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 565 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 566 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 567 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 568 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 569 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 570 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 571 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 572 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00163
# epoch: 573 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 574 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 575 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 576 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 577 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 578 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 579 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 580 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 581 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 582 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 583 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 584 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 585 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 586 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 587 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 588 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00166
# epoch: 589 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00165
# epoch: 590 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00163
# epoch: 591 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00163
# epoch: 592 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 593 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 594 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 595 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00162
# epoch: 596 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00162
# epoch: 597 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 598 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 599 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 600 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 601 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 602 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 603 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 604 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 605 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00159
# epoch: 606 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00159
# epoch: 607 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00159
# epoch: 608 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00159
# epoch: 609 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00159
# epoch: 610 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 611 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 612 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 613 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 614 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 615 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 616 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 617 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 618 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 619 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 620 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 621 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 622 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 623 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 624 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 625 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 626 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 627 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 628 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 629 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 630 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 631 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 632 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 633 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 634 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 635 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 636 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 637 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00162
# epoch: 638 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00162
# epoch: 639 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 640 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 641 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 642 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00160
# epoch: 643 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00161
# epoch: 644 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00162
# epoch: 645 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00162
# epoch: 646 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00163
# epoch: 647 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 648 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# epoch: 649 loss:0.00001 loss_u: 0.00000 loss_f: 0.00001 L2_error: 0.00164
# ...
# epoch: 4788 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4789 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4790 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4791 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4792 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4793 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4794 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4795 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00010
# epoch: 4796 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4797 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4798 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4799 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4800 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4801 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4802 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4803 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4804 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4805 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4806 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4807 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4808 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4809 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4810 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4811 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4812 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4813 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4814 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4815 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4816 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4817 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4818 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4819 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4820 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4821 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4822 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4823 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4824 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4825 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4826 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4827 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4828 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4829 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4830 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4831 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4832 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4833 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4834 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4835 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4836 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00009
# epoch: 4837 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4838 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4839 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4840 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4841 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4842 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4843 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4844 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4845 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4846 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4847 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4848 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4849 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4850 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4851 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4852 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4853 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4854 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4855 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4856 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4857 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4858 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4859 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4860 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4861 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4862 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4863 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4864 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4865 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4866 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4867 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4868 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4869 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4870 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4871 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4872 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4873 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4874 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4875 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4876 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4877 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4878 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4879 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4880 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4881 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4882 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4883 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4884 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4885 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4886 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4887 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4888 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4889 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4890 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4891 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4892 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4893 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4894 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4895 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4896 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4897 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4898 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4899 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4900 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4901 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4902 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4903 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4904 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4905 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4906 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4907 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4908 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4909 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4910 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4911 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4912 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4913 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4914 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4915 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4916 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4917 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4918 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4919 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4920 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4921 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4922 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4923 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4924 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4925 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4926 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4927 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4928 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4929 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4930 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4931 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4932 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4933 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4934 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4935 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4936 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4937 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4938 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4939 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4940 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4941 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4942 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4943 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4944 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4945 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4946 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4947 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4948 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4949 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4950 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4951 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4952 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4953 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4954 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4955 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4956 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4957 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4958 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4959 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4960 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4961 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4962 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4963 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4964 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4965 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4966 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4967 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4968 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4969 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4970 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4971 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4972 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4973 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4974 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4975 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4976 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4977 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4978 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4979 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4980 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4981 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4982 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4983 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4984 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4985 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4986 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4987 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4988 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4989 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4990 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4991 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4992 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4993 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4994 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4995 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4996 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4997 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4998 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 4999 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008
# epoch: 5000 loss:0.00000 loss_u: 0.00000 loss_f: 0.00000 L2_error: 0.00008

# %% [markdown]
# ## Print and Plot the Result

# %%
print(results)
sa_pinn.set_weights(results.x)
# Out:
#   message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#   success: False
#    status: 1
#       fun: 1.1133837252229821e-07
#         x: [ 4.009e-01  1.931e-01 ... -1.485e-01  2.360e-02]
#       nit: 5000
#       jac: [ 8.165e-06  1.477e-05 ...  2.661e-06  1.947e-06]
#      nfev: 5396
#      njev: 5396
#  hess_inv: <4321x4321 LbfgsInvHessProduct with dtype=float64>

# %%
# L2 error of the model
u_pred = sa_pinn(X_u_test).numpy()
L2_error = np.linalg.norm((u_e - u_pred), 2) / np.linalg.norm(u_e, 2)
print(f'Test set L2 error: {L2_error:5f}')

# loss score of the model
loss, loss_f, loss_u = sa_pinn.loss(X_u_train, u_train, X_f_train)
print(f"loss:{loss} loss_u: {loss_u} loss_f: {loss_f}")
# Out:
# Test set L2 error: 0.000080
# loss:1.1133837252229821e-07 loss_u: 1.0441228774891264e-07 loss_f: 6.926084773385563e-09

# %%
# plot

u_e_for_plot = np.reshape(u_e, (t_test.shape[0], x_test.shape[0]))
u_e_for_plot = np.transpose(u_e_for_plot)

plt.imshow(u_e_for_plot, cmap='rainbow', aspect='auto')
plt.colorbar()
plt.title('Exact solution')
plt.show()
plt.close()

u_pred_for_plot = np.reshape(u_pred, (t_test.shape[0], x_test.shape[0]))
u_pred_for_plot = np.transpose(u_pred_for_plot)
plt.imshow(u_pred_for_plot, cmap='rainbow', aspect='auto')
plt.colorbar()
plt.title('SA-PINN solution')
plt.show()
plt.close()

ax = plt.axes(projection='3d')
ax.plot_surface(X, T, u_e_for_plot.T, cmap='rainbow')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('u(x, t)')
ax.set_title('Exact Solution')
plt.show()

ax = plt.axes(projection='3d')
ax.plot_surface(X, T, u_pred_for_plot.T, cmap='rainbow')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('u(x, y)')
ax.set_title('SA-PINN Solution')
plt.show()

# %% [markdown]
# ## Save Model
#
# **Important: You have to use the same dataset as the above dataset to import and use this saved model. Other datasets will cause error and will cause inacurate result.**
#
# Data to save:
#
# - model's layers => layers (use layers to initialize model)
# - model's weights => sa_pinn.get_weights()  (use SA_PINN.set_weight() to set new model's weights)
# - model's adaptive weights => sa_pinn.u_weights, sa_pinn.f_weights

# %%
import json

data_dict = {
    "layers": layers.tolist(),
    "model_weights": sa_pinn.get_weights().numpy().tolist(),
    "model_adaptive_weights": [sa_pinn.u_weights.numpy().tolist(), sa_pinn.f_weights.numpy().tolist()]
}

data_json = json.dumps(data_dict, indent=4)

with open('SAPINNmodel.json', 'w') as f:
    f.write(data_json)
